# %%
import pandas as pd

# %%
df_raw = pd.read_csv("../../0_database/tracking/track_localize_classify_annotation-2022_05_13.csv")
df_raw
# Out:
#                            image  track_id  bb_topleft_x  bb_topleft_y  \
# 0       20220513203542-00-01.jpg       NaN          3422           958
# 1       20220513203542-00-01.jpg       NaN           620           971
# 2       20220513203542-00-01.jpg       NaN          2977           805
# 3       20220513203542-00-01.jpg       NaN          2151             0
# 4       20220513203542-00-01.jpg       NaN          1073           807
# ...                          ...       ...           ...           ...
# 15512  20220513235946-00-114.jpg       NaN           282           260
# 15513  20220513235946-00-114.jpg       NaN           522           762
# 15514  20220513235946-00-114.jpg       NaN          2975           805
# 15515  20220513235946-00-114.jpg       NaN          1073           808
# 15516  20220513235946-00-114.jpg     405.0          1915             0
#
#        bb_botright_x  bb_botright_y  bb_centre_x  bb_centre_y    class  \
# ...
